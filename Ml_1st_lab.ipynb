# %% [markdown]
# <a href="https://colab.research.google.com/github/shxdabb/ML-Lab/blob/main/Ml_1st_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Load Excel file
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/houseprice.xlsx')
print(df.head())


X = df[['Area(sq.feet)']]
y = df['Price(Rs. Lacs']


model = LinearRegression()
model.fit(X, y)


predictions = model.predict(X)

print("Predicted Prices:", predictions)


plt.scatter(X, y, color='blue', label='Actual')
plt.plot(X, predictions, color='red', label='Predicted')
plt.xlabel('Area(sq.feet)')
plt.ylabel('Price')
plt.title('Simple Linear Regression: Area vs Price')
plt.legend()
plt.grid(True)
plt.show()
# Out:
#    Area(sq.feet)  Price(Rs. Lacs
# 0            500           20.00
# 1            525           21.00
# 2            551           22.05
# 3            579           23.15
# 4            608           24.31
# Predicted Prices: [ 20.00034277  21.00032191  22.04030021  23.16027685  24.32025265
#   25.52022762  26.80020092  28.16017255  29.56014335  31.04011247
#   32.56008077  34.20004656  35.92001068  37.71997313  39.59993391
#   41.55989303  43.63984964  45.83980374  48.11975618  50.51970612
#   53.07965272  55.71959765  58.51953924  61.43947833  64.51941408
#   67.71934732  71.1192764   74.67920214  78.39912454  82.31904277
#   86.43895682  90.75886671  95.27877242 100.07867229 105.07856799
#  110.31845868 115.83834354 121.63822255 127.71809572 134.07796305]

# %%
print(df.head(20))
# Out:
#     Area(sq.feet)  Price(Rs. Lacs
# 0             500           20.00
# 1             525           21.00
# 2             551           22.05
# 3             579           23.15
# 4             608           24.31
# 5             638           25.53
# 6             670           26.80
# 7             704           28.14
# 8             739           29.55
# 9             776           31.03
# 10            814           32.58
# 11            855           34.21
# 12            898           35.92
# 13            943           37.71
# 14            990           39.60
# 15           1039           41.58
# 16           1091           43.66
# 17           1146           45.84
# 18           1203           48.13
# 19           1263           50.54

# %%
# Define feature and target
X = df[['Area(sq.feet)']]  # Area of house
y = df['Price(Rs. Lacs']   # Price of house

# %%
# Train the model
model = LinearRegression()
model.fit(X, y)

# Make predictions
predictions = model.predict(X)

# %%
# Show predictions
print("Predicted Prices:", predictions)

# Plot results
plt.scatter(X, y, color='blue', label='Actual')
plt.plot(X, predictions, color='red', label='Predicted')
plt.xlabel('Area')
plt.ylabel('Price Rs.(lacs)')
plt.title('Simple Linear Regression: Area vs Price')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Predicted Prices: [ 20.00034277  21.00032191  22.04030021  23.16027685  24.32025265
#   25.52022762  26.80020092  28.16017255  29.56014335  31.04011247
#   32.56008077  34.20004656  35.92001068  37.71997313  39.59993391
#   41.55989303  43.63984964  45.83980374  48.11975618  50.51970612
#   53.07965272  55.71959765  58.51953924  61.43947833  64.51941408
#   67.71934732  71.1192764   74.67920214  78.39912454  82.31904277
#   86.43895682  90.75886671  95.27877242 100.07867229 105.07856799
#  110.31845868 115.83834354 121.63822255 127.71809572 134.07796305]

# %%
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
import pandas as pd



# Feature and target
X = df[['Area(sq.feet)']]
y = df['Price(Rs. Lacs']

model = LinearRegression()
model.fit(X, y)

# Predict
y_pred = model.predict(X)

# Calculate R² score
r2 = r2_score(y, y_pred)
print(f"R² Score: {r2:.4f}")
# Out:
# R² Score: 1.0000
